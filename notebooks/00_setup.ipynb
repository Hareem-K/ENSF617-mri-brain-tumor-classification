# %%
# Mount Drive and set project path

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Setup

exec(open('/content/drive/MyDrive/brain_tumor_classification/setup_colab.py').read())
# Out:
# ======================================================
#   Step 1 — Detecting environment
# ======================================================
#   Running in Colab : True
#   Python version   : 3.12.13
#   OS               : Linux 6.6.113+
#
# ======================================================
#   Step 2 — Setting up project path
# ======================================================
#   Project root : /content/drive/MyDrive/brain_tumor_classification
#
# ======================================================
#   Step 3 — Creating project structure
# ======================================================
#   Folder structure created.
#
#   /content/drive/MyDrive/brain_tumor_classification/
#     ├── data/
#     ├── src/
#     ├── experiments/
#     ├── outputs/
#     ├── notebooks/
#     ├── logs/
#
# ======================================================
#   Step 4 — Installing dependencies
# ======================================================
#   Installing from: /content/drive/MyDrive/brain_tumor_classification/requirements.txt
#   This may take 2–3 minutes...
#
#   $ pip install -q -r /content/drive/MyDrive/brain_tumor_classification/requirements.txt
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 84.0 MB/s eta 0:00:00
#
#   All dependencies installed.
#
# ======================================================
#   Step 5 — Dataset
# ======================================================
#   Dataset not found. Setting up Kaggle credentials...
#   $ cp /content/drive/MyDrive/kaggle.json /root/.kaggle/kaggle.json
#   $ chmod 600 /root/.kaggle/kaggle.json
#   Kaggle credentials loaded from Drive.
#
#   Downloading dataset (this takes 2–5 minutes)...
#   $ kaggle datasets download -d masoudnickparvar/brain-tumor-mri-dataset -p /content/drive/MyDrive/brain_tumor_classification/data --unzip
# Dataset URL: https://www.kaggle.com/datasets/masoudnickparvar/brain-tumor-mri-dataset
# License(s): Attribution 4.0 International (CC BY 4.0)
# Downloading brain-tumor-mri-dataset.zip to /content/drive/MyDrive/brain_tumor_classification/data
#   Dataset downloaded and extracted.
#
# ======================================================
#   Step 6 — Dataset verification
# ======================================================
#   Training/glioma           1400 images   OK
#   Training/meningioma       1400 images   OK
#   Training/notumor          1400 images   OK
#   Training/pituitary        1400 images   OK
#   Testing/glioma            400 images   OK
#   Testing/meningioma        400 images   OK
#   Testing/notumor           400 images   OK
#   Testing/pituitary         400 images   OK
#
# ======================================================
#   Setup Complete
# ======================================================
#
#   Everything is installed and your dataset is ready.
#
#   IMPORTANT — do this now:
#   ────────────────────────────────────────────────
#   Go to  Runtime → Restart session
#   ────────────────────────────────────────────────
#
#   After restarting, run Cell 2 in your notebook
#   to verify all libraries load correctly.

# %%
# CELL 2 — Verify (run after restart)
from google.colab import drive
drive.mount('/content/drive')

import sys
sys.path.insert(0, '/content/drive/MyDrive/brain_tumor_classification')

import torch, timm, albumentations, cv2, sklearn, matplotlib, numpy

print("=" * 45)
print(f"  PyTorch        : {torch.__version__}")
print(f"  CUDA           : {torch.cuda.is_available()}")
print(f"  GPU            : {torch.cuda.get_device_name(0)}")
print(f"  NumPy          : {numpy.__version__}")
print(f"  OpenCV         : {cv2.__version__}")
print(f"  timm           : {timm.__version__}")
print(f"  albumentations : {albumentations.__version__}")
print(f"  scikit-learn   : {sklearn.__version__}")
print("=" * 45)
print("Complete")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# =============================================
#   PyTorch        : 2.10.0+cu128
#   CUDA           : True
#   GPU            : Tesla T4
#   NumPy          : 2.0.2
#   OpenCV         : 4.13.0
#   timm           : 1.0.25
#   albumentations : 2.0.8
#   scikit-learn   : 1.6.1
# =============================================
# Complete
